# %% [markdown]
# # Chapter 3 Exercies

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# (1a) The null hypothesis H0 is:<br>
# - No relationship between amount on TV ads and Sales.
# - No relationship between amount on radio ads and sales
# - No relationship between amount on newspaper ads  and sales.
# - P-value for TV is <0.0001 meaning that the relationship seen between TV and sales is unlikely to be due to chance and therefore we can reject H0 for TV.<br>
# - Small P-value for radio- meaning we can reject the null hypothesis for radio too.
# - P-value for t-statistic for newspaper is high suggesting we cannot reject the null hypothesis. Suggests there is no significant relationship between newspaper ads and sales.

# %% [markdown]
# (2a) KNN classifier and regression methods both use 'K' nearest data points to determine the label or value of a new point.
# The classifier determines a decision boundary which can be used to seghment data into 2 or more clusters/groups.
# KNN regression is a non-parametric methods for estimating a regression function that can be used to predict some quantitive variable.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# (3a)
#
# - $y = 50 + \beta_0 X1 + \beta_2X2 + \beta_3X3 + \beta_4X4 + \beta_X5 $
# - X3 is an indicator fn, 1 if lvl = college, else 0
# - X4 is an interaction term $X4 = X1\cdot X2$
# - X5 is an interaction term $X5 = X1\cdot X3$
#  - Since IQ and GPA are fixed starting_salary eqn can be simplified:
#   $y = K + \beta_3X3 + + \beta_X5 $
#     - Where $K = 50 + \beta_0 X1 + \beta_2X2 + \beta_4X4 $
#
#
#   $ \implies y = K + \beta_3X3 + \beta_5 X1 \cdot X3 $
#
# - For highschool students $X3 = 0 \implies y=k $
# - For college students $X3 = 1 \implies y = K + \beta_3X3 + \beta_5 X1 $
#
#
# $ y_{coll} - y_{hs} = 35X3  -10 X1$, where X1 = GPA
#
# -if gpa is small then college grads make more
# -if gpa is large then 35-10X1 < 0 so highschool students earn more on average
# -Therefore III is true
#  - For a fixed value of IQ and GPA, highschool students earn more on avg than college students provided that the GPA is high enough

# %% [markdown]
# (b)
# X1 = 4.0
# X2 = 110
# X3 = 1
#
# y = 50 + 20*4.0 + 0.07*110 + 35*1 + 0.01*X1*X2 - 10*X1*X3
# y = 50 + 80 + 7.7 + 35 + 0.01 * 4.0*110 - 10*4.0*1
# y = 137.1 * 1000
# 137,100.00

# %% [markdown]
# (c)
# False, the coefficient is small but still has an effect.
# The magnitude of the coefficient does not tell us much we need to the know the statistical signifacnce e.g p-value or confidence interval.
# Statistical significance depends on the variability in the data and the sample size. If the sample size is large enough, even a small coefficient could be statistically significant.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (a) We expect the cubic model RSS to be the same same or lower than the linear regression because it is more flexible than linear regression model and includes all the terms of the prior. Therefore it can fit the data at least as well as the linear regression

# %% [markdown]
# (b) We would expect the test RSS for the linear regression to be lower because the assumption of high bias is correct and so the lack of flexibility in that model is of no cost in estimating the true f(x). The cubic model is more flexible, and so is likely to overfit the training data meaning that the fit of the model will be affected by variance in the training data that is not representive of the true f(x).
#
# Since the true relationship is linear, the additional terms in the cubic regression model will fit the noise in the training data, rather than the true underlying relationship.
# This overfitting leads to a lower training RSS, but it reduces the model's ability to generalize to new test data, as the extra terms capture noise rather than signal.
#
# The linear model has a higher bias because it assumes a simpler (linear) relationship, but it also has lower variance, as it does not try to fit the noise in the data.
# The cubic model has lower bias because it can represent more complex relationships, but it has higher variance, as it is more sensitive to fluctuations in the training data.

# %% [markdown]
# (c) If we don't know how linear the relationship is, the RSS for the cubic model should be lower than the regression model. As it is more flexible it can fit to the higher variance.
#
# We expect training RSS to decrease as the the variance/flexibility of our model increases. This holds true regardles of the true value of f(x). So we expect the cubic model to result in a lower training RSS

# %% [markdown]
# (d) Need more information

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (5)
# $$
# \hat{y} = x_i \cdot \frac{\sum_i^n x_iy_i}{\sum^n_kx_k^2}
# $$
#
# Distribute the $x_i$ over the sum
#
# $$
# \hat{y} =   \frac{\sum_j^n x_jx_iy_j}{\sum^n_kx_k^2}
# \implies  \hat{y} =  \sum_j^n a_jy_j
# $$
# where $a_j = \frac{\sum_j^n x_jx_i}{\sum^n_kx_k^2}
#  $

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# (6) When $ \bar{x} = x, \bar{y} = y $
# $$
# \hat{y} = \hat{\beta_0} + \hat{\beta_1}X
# = \hat{\beta_0} + \hat{\beta_1}\bar{x}
# $$
#
# $$
# = \bar{y} - \hat{\beta_1}\bar{x} + \hat{\beta_1}\bar{x} = \bar{y}
#
# $$

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# (7)
# ### Derivation of $( R^2 = \text{Cor}(x, y)^2 )$ in Simple Linear Regression
#
# #### Assumptions:
# 1. Mean of \(x\) and \(y\) is zero: $ \bar{x} = \bar{y} = 0\ $.
# 2. Simple linear regression model: $(y_i = \beta x_i + \epsilon_i).$
#
# ---
#
# #### Definition of $(R^2)$:
# $[
# R^2 = \frac{\text{TSS} - \text{RSS}}{\text{TSS}} = 1 - \frac{\text{RSS}}{\text{TSS}} =  \frac{\text{ESS}}{\text{TSS}},
# ]$
# where:
# -  $ (\text{TSS} = \sum_{i=1}^n y_i^2) $ (Total Sum of Squares),
# - $(\text{RSS} = \sum_{i=1}^n (y_i - \hat{y}_i)^2)$ (Residual Sum of Squares),
# - $(\text{ESS} = \sum_{i=1}^n \hat{y}_i^2)$ (Explained Sum of Squares).$
#
#
# Given that $( \hat{y}_i = \beta x_i )$, we can write:
# $[
# \text{ESS} = \sum_{i=1}^n (\hat{y}_i)^2 = \beta^2 \sum_{i=1}^n x_i^2.
# ]$
#
#
# ---
#
# #### Estimate for $(\beta)$:
# $[
# \beta = \frac{\sum_{i=1}^n x_i y_i}{\sum_{i=1}^n x_i^2}.
# ]$
#
# Substituting $(\beta)$ into $(\text{ESS})$:
# $[
# \text{ESS} = \left(\frac{\sum_{i=1}^n x_i y_i}{\sum_{i=1}^n x_i^2}\right)^2 \sum_{i=1}^n x_i^2 = \frac{(\sum_{i=1}^n x_i y_i)^2}{\sum_{i=1}^n x_i^2}.
# ]$
#
# ---
#
# #### TSS:
# $[
# \text{TSS} = \sum_{i=1}^n y_i^2.
# ]$
#
# ---
#
# #### $(R^2)$:
# $[
# R^2 = \frac{\text{ESS}}{\text{TSS}} = \frac{\frac{(\sum_{i=1}^n x_i y_i)^2}{\sum_{i=1}^n x_i^2}}{\sum_{i=1}^n y_i^2}.
# ]$
#
# Simplify:
# $[
# R^2 = \frac{(\sum_{i=1}^n x_i y_i)^2}{\sum_{i=1}^n x_i^2 \cdot \sum_{i=1}^n y_i^2}.
# ]$
#
# ---
#
# #### Correlation $((\text{Cor}(x, y)))$:
# The correlation between \(x\) and \(y\) is:
# $[
# \text{Cor}(x, y) = \frac{\sum_{i=1}^n x_i y_i}{\sqrt{\sum_{i=1}^n x_i^2 \cdot \sum_{i=1}^n y_i^2}}.
# ]$
#
# Square it:
# $[
# \text{Cor}(x, y)^2 = \frac{(\sum_{i=1}^n x_i y_i)^2}{\sum_{i=1}^n x_i^2 \cdot \sum_{i=1}^n y_i^2}.
# ]$
#
# ---
#
# #### Conclusion:
# $[
# R^2 = \text{Cor}(x, y)^2.
# ]$

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
from matplotlib .pyplot import subplots
import statsmodels .api as sm
from statsmodels .stats. outliers_influence \
import variance_inflation_factor as VIF
from statsmodels .stats.anova import anova_lm
from ISLP import load_data
from ISLP.models import ( ModelSpec as MS ,
summarize ,
poly)
import statsmodels.formula.api as smf
import seaborn as sns

# %%
Auto = load_data('Auto')
Auto.columns
Auto.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
Auto.shape
# Out:
# (392, 8)

# %% [markdown]
# $$
#  \mathbf{y} = \mathbf{X} \boldsymbol{\beta} + \boldsymbol{\varepsilon}
#
#
# $$
# Remember these are vectors, why we need a column of ones so when we multipying out we get B0(1) + B1Xi

# %%
X = pd.DataFrame({'intercept': np.ones(Auto.shape[0]), 'horsepower': Auto['horsepower']})
X[:4]
# Out:
#                            intercept  horsepower
# name
# chevrolet chevelle malibu        1.0         130
# buick skylark 320                1.0         165
# plymouth satellite               1.0         150
# amc rebel sst                    1.0         150

# %%
y = Auto['mpg']
model = sm.OLS(y, X)
result = model.fit()
summarize(result)
# Out:
#                coef  std err       t  P>|t|
# intercept   39.9359    0.717  55.660    0.0
# horsepower  -0.1578    0.006 -24.489    0.0

# %% [markdown]
# (ai)
# - Strong relationship  between horsepower and mpg, small standard error and large t-statistic with a very small pvalue
# - Means this relationship is unlikely to be due to chance and there is a relationship between hp and mpg

# %%
result.rsquared
# Out:
# 0.6059482578894348

# %%
rse = np.sqrt(result.scale)
rse
# Out:
# 4.90575691954594

# %%
lack_fit=rse/np.mean(Auto["mpg"])
lack_fit
# Out:
# 0.20923714066914834

# %% [markdown]
# (aii)
# - Around 60% of the variability of mpg can be explained by horsepower.
# - RSE tells us we deviate by about 4.9 mpg
# - The lack of fit tells us model fails to represetn about 20.1% of the data

# %% [markdown]
# (aiii)
# - negative correlation i.e mpg goes up when hp goes down

# %% [markdown]
# (aiv)

# %%
#aiv predicted mpg with hp = 98 and 95% CI and prediction interval
result.get_prediction([1, 98]).summary_frame(alpha=0.05)
# Out:
#         mean   mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0  24.467077  0.251262      23.973079      24.961075     14.809396
#
#    obs_ci_upper
# 0     34.124758

# %% [markdown]
# ## b)

# %%
def abline(ax, b, m, *args, **kwargs):
    "Add a line with slope m and intercept b to ax"
    xlim = ax.get_xlim()
    ylim = [m * xlim[0] + b, m * xlim[1] + b]
    ax.plot(xlim, ylim, *args, **kwargs)

# %%
ax = Auto.plot.scatter('horsepower', 'mpg')
abline(ax, result.params['intercept'], result.params['horsepower'],  'r--',
       linewidth=3)

# %% [markdown]
# (c) Diagnostic plots
#  - residuls against fitted values
#  - leverage stats
#  - studentised residuals

# %%
ax = subplots(figsize=(8,8))[1]
ax.scatter(result.fittedvalues, result.resid)
ax.set_xlabel('Fitted value')
ax.set_ylabel('Residual')
ax.axhline(0, c='k', ls='--');

# %% [markdown]
# There is a clear funnel shape which means there is non constant variance of error terms
# Relationship is also highly non linear

# %%
infl = result.get_influence()
ax = subplots(figsize=(8,8))[1]
ax.scatter(np.arange(X.shape[0]), infl.hat_matrix_diag)
ax.set_xlabel('Index')
ax.set_ylabel('Leverage')
np.argmax(infl.hat_matrix_diag)
# Out:
# 115

# %%
# calculate the leverage threshold
n, p = X.shape
leverage_threshold = 2 * p / n
leverage_threshold
# Out:
# 0.01020408163265306

# %%
n
# Out:
# 392

# %%
avg_lev = p/n #np.mean(infl.hat_matrix_diag)  same as p/n
avg_lev
# Out:
# 0.00510204081632653

# %% [markdown]
# The highest leverage statistic has a value of 0.03 which is higher than the threshold

# %%
# what is index 115
Auto.iloc[115]
# Out:
# mpg               16.0
# cylinders          8.0
# displacement     400.0
# horsepower       230.0
# weight          4278.0
# acceleration       9.5
# year              73.0
# origin             1.0
# Name: pontiac grand prix, dtype: float64

# %%
feature_means = Auto.mean()
feature_stds = Auto.std()
print(feature_means)
print(feature_stds)
# Out:
# mpg               23.445918
# cylinders          5.471939
# displacement     194.411990
# horsepower       104.469388
# weight          2977.584184
# acceleration      15.541327
# year              75.979592
# origin             1.576531
# dtype: float64
# mpg               7.805007
# cylinders         1.705783
# displacement    104.644004
# horsepower       38.491160
# weight          849.402560
# acceleration      2.758864
# year              3.683737
# origin            0.805518
# dtype: float64

# %%
# Calculate the z-scores for each feature
z_scores = (Auto.iloc[115] - feature_means) / feature_stds

# Display the z-scores
print(z_scores)
# Out:
# mpg            -0.953992
# cylinders       1.482053
# displacement    1.964642
# horsepower      3.261284
# weight          1.530977
# acceleration   -2.189788
# year           -0.808850
# origin         -0.715726
# dtype: float64

# %% [markdown]
# A z-score indicates how many standard deviations a data point is from the mean. A z-score above 2 or below -2 suggests that the feature value is significantly different from the dataset average, potentially contributing to high leverage, as confirmed the hp is extreme compared to rest of the data point so we should consider removing.

# %%
#Draw studentized residuals against fitted values
ax=subplots(figsize=(8,8))[1]
studentized_residuals = result.get_influence().resid_studentized_internal
ax.scatter(result.fittedvalues,studentized_residuals)
ax.set_xlabel("Fitted values")
ax.set_ylabel("Studentized residuals");

# %%
df=pd.DataFrame({'fitted':result.fittedvalues,'studentized':studentized_residuals})
df[df['studentized']>3]
# Out:
#                         fitted  studentized
# name
# mazda glc            29.675953     3.458909
# honda civic 1500 gl  29.360264     3.114256

# %% [markdown]
# These 2 points are seen to be outliers

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#(a) scatter plot matrix of all variables in Auto
Auto = load_data('Auto')
pd.plotting.scatter_matrix(Auto, figsize=(12,12))
# Out:
# array([[<Axes: xlabel='mpg', ylabel='mpg'>,
#         <Axes: xlabel='cylinders', ylabel='mpg'>,
#         <Axes: xlabel='displacement', ylabel='mpg'>,
#         <Axes: xlabel='horsepower', ylabel='mpg'>,
#         <Axes: xlabel='weight', ylabel='mpg'>,
#         <Axes: xlabel='acceleration', ylabel='mpg'>,
#         <Axes: xlabel='year', ylabel='mpg'>,
#         <Axes: xlabel='origin', ylabel='mpg'>],
#        [<Axes: xlabel='mpg', ylabel='cylinders'>,
#         <Axes: xlabel='cylinders', ylabel='cylinders'>,
#         <Axes: xlabel='displacement', ylabel='cylinders'>,
#         <Axes: xlabel='horsepower', ylabel='cylinders'>,
#         <Axes: xlabel='weight', ylabel='cylinders'>,
#         <Axes: xlabel='acceleration', ylabel='cylinders'>,
#         <Axes: xlabel='year', ylabel='cylinders'>,
#         <Axes: xlabel='origin', ylabel='cylinders'>],
#        [<Axes: xlabel='mpg', ylabel='displacement'>,
#         <Axes: xlabel='cylinders', ylabel='displacement'>,
# ...

# %%
#(b) correlation matrix
Auto.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# year          0.580541  -0.345647     -0.369855   -0.416361 -0.309120
# origin        0.565209  -0.568932     -0.614535   -0.455171 -0.585005
#
#               acceleration      year    origin
# mpg               0.423329  0.580541  0.565209
# cylinders        -0.504683 -0.345647 -0.568932
# displacement     -0.543800 -0.369855 -0.614535
# horsepower       -0.689196 -0.416361 -0.455171
# weight           -0.416839 -0.309120 -0.585005
# acceleration      1.000000  0.290316  0.212746
# ...

# %%
# (c) multiple linear regression model of all variables apart from name
fts = Auto.columns.drop(['mpg'])
X = MS(fts).fit_transform(Auto)
y = Auto['mpg']
mlr = sm.OLS(y, X)
results = mlr.fit()

summarize(results)
# Out:
#                  coef  std err       t  P>|t|
# intercept    -17.2184    4.644  -3.707  0.000
# cylinders     -0.4934    0.323  -1.526  0.128
# displacement   0.0199    0.008   2.647  0.008
# horsepower    -0.0170    0.014  -1.230  0.220
# weight        -0.0065    0.001  -9.929  0.000
# acceleration   0.0806    0.099   0.815  0.415
# year           0.7508    0.051  14.729  0.000
# origin         1.4261    0.278   5.127  0.000

# %% [markdown]
# #

# %%
#i)
res1=smf.ols('y~X',data=Auto).fit()
anova_lm(res1)
# Out:
#              df        sum_sq      mean_sq           F         PR(>F)
# X           8.0  19575.989106  2446.998638  220.978484  1.327873e-138
# Residual  384.0   4252.212530    11.073470         NaN            NaN

# %% [markdown]
# F statistic is much larger than 1 therefore null hypothesis must be rejected

# %% [markdown]
# (ii)
# Weight, displacement, year and origin all have a strong relationship with mpg

# %% [markdown]
# (iii)

# %% [markdown]
# Postive coefficient therefore there is a positive correlation i.e increase in one year causes increase of 0.75 mpg, all other factors const

# %% [markdown]
# (d)

# %%
#Draw residuals against fitted values
ax=subplots(figsize=(10,10))[1]
ax.scatter(results.fittedvalues,results.resid)
sns.residplot(data=Auto,x=results.fittedvalues,y='mpg',lowess=True)
ax.set_xlabel("Fitted values")
ax.set_ylabel("Residuals")
# Out:
# Text(0, 0.5, 'Residuals')

# %% [markdown]
# Some evidence of non linearity and funnel shape means there is a non const variance in errors

# %%
# Plot the leverage stats
infl = results.get_influence()
ax = subplots(figsize=(8,8))[1]
ax.scatter(np.arange(X.shape[0]), infl.hat_matrix_diag)
ax.set_xlabel('Index')
ax.set_ylabel('Leverage')
np.argmax(infl.hat_matrix_diag)
# Out:
# 13

# %%
# calculate the leverage threshold
n, p = X.shape
leverage_threshold = 2 * p / n
leverage_threshold
# Out:
# 0.04081632653061224

# %%
avg = p/n
avg
# Out:
# 0.02040816326530612

# %%
infl.hat_matrix_diag[13]
# Out:
# 0.18991288602616593

# %% [markdown]
# Bigger than leverage threshold and average threshold by factor of 10.
# Significant and should be investigated

# %%
#Draw studentized residuals against fitted values
ax=subplots(figsize=(10,10))[1]
studentized_residuals = results.get_influence().resid_studentized_internal
ax.scatter(results.fittedvalues,studentized_residuals)
ax.set_xlabel("Fitted values")
ax.set_ylabel("Studentized residuals");

# %%
df=pd.DataFrame({'fitted':results.fittedvalues,'studentized':studentized_residuals})
df[np.abs(df['studentized'])>3]
# Out:
#                                     fitted  studentized
# name
# volkswagen rabbit custom diesel  32.078967     3.344681
# mazda glc                        33.539573     3.951894
# vw rabbit c (diesel)             32.949224     3.444885
# vw dasher (diesel)               31.491864     3.631071

# %% [markdown]
# These are outliers

# %% [markdown]
# X = MS(['lstat',
#         'age',
#         ('lstat', 'age')]).fit_transform(Boston)
# model2 = sm.OLS(y, X)
# summarize(model2.fit())
#
# or
# model2 = smf.ols(formula='mpg ~ displacement*origin + year', data=Auto) # the formula automatically

# %%
#Let's try out some interaction terms
model2 = smf.ols(formula='mpg ~ displacement*origin + year', data=Auto) # the formula automatically
# applies the hierarchy principle
print(summarize(model2.fit()))
model3 = smf.ols(formula='mpg ~ horsepower*weight +origin', data=Auto)
print(summarize(model3.fit()))
# Out:
#                         coef  std err       t  P>|t|
# Intercept           -32.6362    4.725  -6.907  0.000
# displacement          0.0065    0.009   0.712  0.477
# origin                6.5265    0.946   6.902  0.000
# displacement:origin  -0.0487    0.008  -5.785  0.000
# year                  0.7494    0.056  13.418  0.000
#                        coef   std err       t  P>|t|
# Intercept          59.27830  2.718000  21.807  0.000
# horsepower         -0.24080  0.027000  -8.852  0.000
# weight             -0.00980  0.001000 -11.679  0.000
# horsepower:weight   0.00005  0.000007   7.455  0.000
# origin              0.93090  0.309000   3.017  0.003

# %% [markdown]
# X = MS([poly('lstat', degree=2), 'age']).fit_transform(Boston)
# model3 = sm.OLS(y, X)
# results3 = model3.fit()
# summarize(results3)
#
# or
# model4 = smf.ols(formula='mpg ~ horsepower+np.log(weight) +origin', data=Auto)

# %%
#(f) Try out some new transforms
model4 = smf.ols(formula='mpg ~ horsepower+np.log(weight) +origin', data=Auto)
print(summarize(model4.fit()))

model5 = smf.ols(formula='mpg ~ horsepower+np.sqrt(weight) +origin', data=Auto)
print(summarize(model5.fit()))

model6 = smf.ols(formula='mpg ~ horsepower+np.power(weight,2) +origin', data=Auto)
print(summarize(model6.fit()))
# Out:
#                     coef  std err       t  P>|t|
# Intercept       153.0507   11.717  13.062  0.000
# horsepower       -0.0504    0.010  -5.018  0.000
# np.log(weight)  -15.8235    1.543 -10.253  0.000
# origin            1.0169    0.323   3.148  0.002
#                     coef  std err       t  P>|t|
# Intercept        57.5157    2.678  21.476    0.0
# horsepower       -0.0500    0.011  -4.749    0.0
# np.sqrt(weight)  -0.5678    0.059  -9.672    0.0
# origin            1.1581    0.323   3.580    0.0
#                              coef       std err       t  P>|t|
# Intercept            3.336930e+01  1.002000e+00  33.296    0.0
# horsepower          -6.780000e-02  1.100000e-02  -5.909    0.0
# np.power(weight, 2) -5.903000e-07  8.610000e-08  -6.854    0.0
# origin               1.787200e+00  3.250000e-01   5.507    0.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Carseats = load_data('Carseats')
Carseats.columns
# Out:
# Index(['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price',
#        'ShelveLoc', 'Age', 'Education', 'Urban', 'US'],
#       dtype='object')

# %%
Carseats.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# ...

# %%
Carseats.shape
# Out:
# (400, 11)

# %%
#(a) Multiple regression model  sales ~ price,urban and US
fts = ['Price', 'Urban', 'US']

X = MS(Carseats[fts]).fit_transform(Carseats)
y = Carseats['Sales']
mlr = sm.OLS(y, X)
results = mlr.fit()
summarize(results)
# Out:
#                coef  std err       t  P>|t|
# intercept   13.0435    0.651  20.036  0.000
# Price       -0.0545    0.005 -10.389  0.000
# Urban[Yes]  -0.0219    0.272  -0.081  0.936
# US[Yes]      1.2006    0.259   4.635  0.000

# %% [markdown]
# (b)
# - Urban is not a statisticaly significant predictor for Sales
# - US and Sales is statistically signifcant. In the US sell 1200 units more on avg
# - price significant but has negative correlation i.e $1 increase in price sell 55 units less

# %% [markdown]
# (c)
#
# \begin{equation*}
# Sales = 13.0435 - 0.0545Price + 1.2006US - 0.0219Urban =
# \begin{cases}
#                         13.0435−0.0219×Urban+1.2006×US−0.0545×Price &\text{$Urban=1,US=1$}\\
#                         13.0435−0.0219×Urban+1.2006×Price &\text{$Urban=1,US=0$}\\
#                         13.0435+1.2006×US−0.0545×Price &\text{$Urban=0,US=1$}\\
#                         13.0435−0.0545×Price &\text{$Urban=0,US=0$}\\
# \end{cases}
# \end{equation*}

# %% [markdown]
# (d)
# Reject null hypothesis for price and US

# %%
#(e) Model without urban
fts = ['Price', 'US']

X = MS(Carseats[fts]).fit_transform(Carseats)
y = Carseats['Sales']
mlr = sm.OLS(y, X)
results_no_urban = mlr.fit()
summarize(results_no_urban)
# Out:
#               coef  std err       t  P>|t|
# intercept  13.0308    0.631  20.652    0.0
# Price      -0.0545    0.005 -10.416    0.0
# US[Yes]     1.1996    0.258   4.641    0.0

# %%
print(results_no_urban.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     62.43
# Date:                Mon, 13 Jan 2025   Prob (F-statistic):           2.66e-24
# Time:                        21:14:13   Log-Likelihood:                -927.66
# No. Observations:                 400   AIC:                             1861.
# Df Residuals:                     397   BIC:                             1873.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     13.0308      0.631     20.652      0.000      11.790      14.271
# ...

# %%
print(" The R-squared for the regression model with Urban is ",results.rsquared)
print(" The R-squared for the regression model without Urban is ",results_no_urban.rsquared)
# Out:
#  The R-squared for the regression model with Urban is  0.2392753921840549
#  The R-squared for the regression model without Urban is  0.23926288842678567

# %% [markdown]
# Both models do not fit the data well. low $R^2$ means lots of unexplained variance

# %%
#(g) 95% CI for the new model
results_no_urban.conf_int(alpha=0.05)
# Out:
#                   0          1
# intercept  11.79032  14.271265
# Price      -0.06476  -0.044195
# US[Yes]     0.69152   1.707766

# %%
#(h) outliers or high leverage points
studentized_residuals = results_no_urban.get_influence().resid_studentized_internal
df=pd.DataFrame({'fitted':results_no_urban.fittedvalues,'studentized':studentized_residuals})
df[np.abs(df['studentized'])>3]
# Out:
# Empty DataFrame
# Columns: [fitted, studentized]
# Index: []

# %%
# Plot the leverage stats
infl = results_no_urban.get_influence()
ax = subplots(figsize=(8,8))[1]
ax.scatter(np.arange(X.shape[0]), infl.hat_matrix_diag)
ax.set_xlabel('Index')
ax.set_ylabel('Leverage')
np.argmax(infl.hat_matrix_diag)
# Out:
# 42

# %%
n,p = X.shape
avg = p/n
leverage_threshold = 2 * avg

print("The leverage threshold is ",leverage_threshold)
print("The average leverage is ",avg)
# Out:
# The leverage threshold is  0.015
# The average leverage is  0.0075

# %% [markdown]
# No outliers, 1 high leverage point

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
rng = np.random. default_rng (1)
x = rng.normal(size =100)
y = 2 * x + rng.normal(size =100)

# %%
#(a) y=x 
df=pd.DataFrame({'x':x,'y':y})
X=MS(df[['x']],intercept=False).fit_transform(df)
model=sm.OLS(y,X)
result=model.fit()
summarize(result)
# Out:
#      coef  std err       t  P>|t|
# x  1.9762    0.117  16.898    0.0

# %% [markdown]
# small p value therefore is significatnt and can reject null hypothesis

# %%
#(b) x=y
df=pd.DataFrame({'x':y,'y':x})
X=MS(df[['x']],intercept=False).fit_transform(df)
model=sm.OLS(x,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.743
# Model:                            OLS   Adj. R-squared (uncentered):              0.740
# Method:                 Least Squares   F-statistic:                              285.6
# Date:                Mon, 13 Jan 2025   Prob (F-statistic):                    6.23e-31
# Time:                        21:14:13   Log-Likelihood:                         -58.349
# No. Observations:                 100   AIC:                                      118.7
# Df Residuals:                      99   BIC:                                      121.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# performance is the same but coefficients differ. The coefficient estimates from the two regressions are reciprocals of each other (approximately ). This reciprocal relationship is expected in simple linear regression without an intercept. However, the t-statistics and p-values remain the same in both regressions because they depend on the correlation between  x  and  y , not on the direction of the regression.

# %% [markdown]
# (d)
#
# Recall the logic in RSS (since $\hat{\beta}_0$ = 0 and $\hat{y} = x\hat{\beta}$)
# $$ \text{RSS} = \sum(y-x\hat{\beta}) $$
# $$ \text{RSS} = \sum y^2 - 2\hat{\beta}\sum xy + \hat{\beta}^2 \sum x^2 $$
# $$ \text{RSS} = \frac{\sum y^2 \sum x^2 - (\sum xy)^2}{\sqrt{n-1} \sum x^2} $$
#
# ---
#
# $$ SE(\hat{\beta}) = = \sqrt{\frac{\sum(y-x\hat{\beta)^2}}{(n-1) \sum x^2}}  = \sqrt{\frac{\frac{\sum y^2 \sum x^2 - (\sum xy)^2}{\sum x^2}}{(n-1) \sum x^2}} = \sqrt{\frac{{\sum y^2 \sum x^2 - (\sum xy)^2}}{(n-1) (\sum x^2)^2}}$$
#
# $$ t = \frac{\hat{\beta}}{SE(\hat{\beta})} = \frac{\sum xy}{\sum x^2} \times \frac{\sqrt{n-1} \sqrt{(\sum x^2)^2}}{\sum y^2 \sum x^2 - (\sum xy)^2} = \frac{\sqrt{n-1} \sum xy}{\sum y^2 \sum x^2 - (\sum xy)^2}$$

# %% [markdown]
# (e)
#
# $$ t_{(x,y)} = \frac{\sqrt{n-1} \sum xy}{\sum y^2 \sum x^2 - (\sum xy)^2} = \frac{\sqrt{n-1} \sum yx}{\sum x^2 \sum y^2 - (\sum yx)^2} = t_{(y,x)}$$

# %%
rng = np.random. default_rng (1)
x = rng.normal(size =100)
y = 2 * x + rng.normal(size =100)
df=pd.DataFrame({'x':x,'y':y})

# %%
# regress y onto x
X1=MS(df[['x']]).fit_transform(df)
model1=sm.OLS(y,X1)
result1=model1.fit()
summarize(result1)
# Out:
#              coef  std err       t  P>|t|
# intercept -0.0760    0.101  -0.756  0.451
# x          1.9686    0.118  16.734  0.000

# %%
# regress x onto y
Y1=MS(df[['y']]).fit_transform(df)
model2=sm.OLS(x,Y1)
result2=model2.fit()
summarize(result2)
# Out:
#              coef  std err       t  P>|t|
# intercept  0.0095    0.044   0.216  0.829
# y          0.3763    0.022  16.734  0.000

# %% [markdown]
# t-stats are equal
