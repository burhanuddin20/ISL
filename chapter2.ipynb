# %% [markdown]
# Exercise 8

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
college = pd.read_csv('data/College.csv')

# %%
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
college2 = pd.read_csv('data/College.csv', index_col=0)
college3 = college.rename({'Unnamed: 0': 'College'},
axis=1)
college3 = college3.set_index('College')

# %%
college = college3

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# produce a
# scatterplot matrix of the frst columns [Top10perc, Apps, Enroll].
# Recall that you can reference a list C of columns of a da

# %%
pd.plotting.scatter_matrix(college[["Top10perc", "Apps", "Enroll"]])
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
# (e) Use the boxplot() method of college to produce side-by-side
# boxplots of Outstate versus Private.

# %%
college.boxplot(column='Outstate', by='Private', figsize=(8, 6))
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %% [markdown]
# Create a new qualitative variable, called Elite, by binning the
# Top10perc variable into two groups based on whether or not the
# proportion of students coming from the top 10% of their high
# school classes exceeds 50%.

# %%
# Initialize all rows with "No"
college["Elite"] = "No"
# Update to "Yes" only where Top10perc > 50
college.loc[college["Top10perc"] > 50, "Elite"] = "Yes"

# Check the distribution of your new variable
print(college["Elite"].value_counts())
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %% [markdown]
# Use the value_counts() method of college['Elite'] to see how
# many elite universities there are. Finally, use the boxplot() method
# again to produce side-by-side boxplots of Outstate versus Elite.

# %%
college.boxplot(column='Outstate', by='Elite', figsize=(8, 6))
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %% [markdown]
# Use the plot.hist() method of college to produce some histograms with difering numbers of bins for a few of the quantitative variables. The command plt.subplots(2, 2) may be useful: it will divide the plot window into four regions so that four
# plots can be made simultaneously. By changing the arguments
# you can divide the screen up in other combinations.

# %%
columns_to_plot = ["Outstate", "Room.Board", "Apps", "Enroll"]

# Create a figure with a 2×2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plot histograms on each axis with different bin sizes
college[columns_to_plot[0]].plot.hist(ax=axes[0, 0], bins=10, alpha=0.7)
axes[0, 0].set_title(f"{columns_to_plot[0]} (10 bins)")

college[columns_to_plot[1]].plot.hist(ax=axes[0, 1], bins=20, alpha=0.7)
axes[0, 1].set_title(f"{columns_to_plot[1]} (20 bins)")

college[columns_to_plot[2]].plot.hist(ax=axes[1, 0], bins=15, alpha=0.7)
axes[1, 0].set_title(f"{columns_to_plot[2]} (15 bins)")

college[columns_to_plot[3]].plot.hist(ax=axes[1, 1], bins=25, alpha=0.7)
axes[1, 1].set_title(f"{columns_to_plot[3]} (25 bins)")

# Adjust layout so that subplots do not overlap
plt.tight_layout()
plt.show()

# %% [markdown]
# Exercise 9

# %%
auto = pd.read_csv("data/Auto.csv")

# %%
auto.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# Drop missing values

# %%
# Check for missing values
auto.isnull().any(axis=1).sum() == 0
# ...there are none
# ah, ? is used for missing values
auto = auto.drop(auto[auto.values == '?'].index)
auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# Year and Origin are qualitative rest are quantitative

# %% [markdown]
# What is the range of each quantitative predictor? You can answer this using the min() and max() methods in numpy.

# %% [markdown]
# What is the mean and standard deviation of each quantitative .max()
# predictor?

# %%
datatypes = {'quant': ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration'],
             'qual': ['origin', 'name']}

auto_quant = auto[datatypes['quant']].astype(np.float_)
pd.DataFrame({'range': auto_quant.max() - auto_quant.min(),
              'mean': auto_quant.mean(),
              'std': auto_quant.std()})
# Out:
#                range         mean         std
# mpg             37.6    23.445918    7.805007
# cylinders        5.0     5.471939    1.705783
# displacement   387.0   194.411990  104.644004
# horsepower     184.0   104.469388   38.491160
# weight        3527.0  2977.584184  849.402560
# acceleration    16.8    15.541327    2.758864

# %% [markdown]
# Now remove the 10th through 85th observations. What is the
# range, mean, and standard deviation of each predictor in the
# subset of the data that remains?

# %%
df_subset =  auto_quant.drop(auto_quant.index[10: 85])
pd.DataFrame({'range': df_subset.max() - df_subset.min(),
              'mean': df_subset.mean(),
              'std': df_subset.std()})
# Out:
#                range         mean         std
# mpg             35.6    24.374763    7.872565
# cylinders        5.0     5.381703    1.658135
# displacement   387.0   187.880126  100.169973
# horsepower     184.0   101.003155   36.003208
# weight        3348.0  2938.854890  811.640668
# acceleration    16.3    15.704101    2.719913

# %% [markdown]
# (e) Using the full data set, investigate the predictors graphically,
# using scatterplots or other tools of your choice. Create some plots
# highlighting the relationships among the predictors. Comment on your findings.
#
# combine numeric quantitive data with original qualitive data

# %%
# Convert some columns to categorical if appropriate
auto["cylinders"] = auto["cylinders"].astype("category")
auto["origin"] = auto["origin"].astype("category")

# Check the DataFrame
auto.head()
# Out:
#     mpg cylinders  displacement horsepower  weight  acceleration  year origin  \
# 0  18.0         8         307.0        130    3504          12.0    70      1
# 1  15.0         8         350.0        165    3693          11.5    70      1
# 2  18.0         8         318.0        150    3436          11.0    70      1
# 3  16.0         8         304.0        150    3433          12.0    70      1
# 4  17.0         8         302.0        140    3449          10.5    70      1
#
#                         name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
# Choose quantitative variables of interest
quant_vars = ["mpg", "displacement", "weight", "acceleration","horsepower","cylinders"]

# Create a pairplot colored by 'origin'
sns.pairplot(data=auto, vars=quant_vars, hue="origin", diag_kind="hist")
plt.suptitle("Scatterplot Matrix Colored by 'origin'", y=1.02)
plt.show()

# %%
# mpg vs. cylinders
plt.figure(figsize=(8, 5))
sns.boxplot(x="cylinders", y="mpg", data=auto)
sns.stripplot(x="cylinders", y="mpg", data=auto, color="black", alpha=0.5)
plt.title("MPG by Number of Cylinders")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x="origin", y="mpg", data=auto)
sns.stripplot(x="origin", y="mpg", data=auto, color="black", alpha=0.5)
plt.title("MPG by Origin")
plt.show()

# %% [markdown]
# Suppose that we wish to predict gas mileage (mpg) on the basis
# of the other variables. Do your plots suggest that any of the
# other variables might be useful in predicting mpg? Justify your
# answer.

# %% [markdown]
# mpg appears to correlate strongly with weight, hordsepower and displacement. These relationships are non-linear and appear to be exponential. The distribution of mpg is skewed
# the relationships between displacement, horespower, and weight appear to be linear
# cylinder count correlate positively with displacement, horespower, and weight and negatively with mpg
# the relationship between acceleration and other features seems weekly correlated. horsepower is perhaps most strongly correlated. acceleration has a normal distribution

# %% [markdown]
# Displacement, weight have a strong negative correlation with mpg. Accelearation has a more linear positive correaltion with mpg.
# Origin also seems to have an effect as origin one had median mpg of 18 significantly lower than origin 2 and 3.

# %% [markdown]
# EX 10

# %%
boston = pd.read_csv('data/Boston.csv', index_col=0)

# %%
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 1   4.98  24.0
# 2   9.14  21.6
# 3   4.03  34.7
# 4   2.94  33.4
# 5   5.33  36.2

# %%
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %% [markdown]
# How many rows are in this data set? How many columns? What
# do the rows and columns represent?

# %%
boston.shape
# Out:
# (506, 13)

# %%
pd.plotting.scatter_matrix(boston);

# %%
subset_cols = ["crim", "nox", "rm", "lstat","dis"]
sns.pairplot(boston[subset_cols], diag_kind='hist')
plt.suptitle("Pairwise Scatterplots of Selected Boston Predictors", y=1.02)
plt.show()

# %% [markdown]
# Are any of the predictors associated with per capita crime rate?
# If so, explain the relationship.

# %% [markdown]
# Crime rate can be correlated with LSTAT (higher crime in lower-status areas) and with DIS (perhaps areas closer to city centers). You may see that CRIM is highly skewed, with a few neighborhoods having very high values.

# %% [markdown]
# Do any of the suburbs of Boston appear to have particularly
# high crime rates? Tax rates? Pupil-teacher ratios? Comment on
# the range of each predictor.

# %%
print("Range (min, max, and range) for each predictor:\n")
for col in boston.columns:
    col_min = boston[col].min()
    col_max = boston[col].max()
    col_range = col_max - col_min
    print(f"{col}: min={col_min}, max={col_max}, range={col_range}")
    
# 5. Identify particularly high CRIM (crime rate), TAX (tax rate), PTRATIO (pupil-teacher ratio).
#    Thresholds below are somewhat arbitrary; feel free to adjust.

# Crime rate threshold - let's pick CRIM > 20 as "high"
high_crim = boston[boston['crim'] > 20]
print("\nSuburbs with particularly high crime rates (CRIM > 20):")
print(high_crim)

# Tax rate threshold - let's pick TAX > 600 as "high"
high_tax = boston[boston['tax'] > 600]
print("\nSuburbs with particularly high tax rates (TAX > 600):")
print(high_tax)

# PTRATIO threshold - let's pick PTRATIO > 20 as "high"
high_ptratio = boston[boston['ptratio'] > 20]
print("\nSuburbs with particularly high pupil-teacher ratios (PTRATIO > 20):")
print(high_ptratio)
# Out:
# Range (min, max, and range) for each predictor:
#
# crim: min=0.00632, max=88.9762, range=88.96988
# zn: min=0.0, max=100.0, range=100.0
# indus: min=0.46, max=27.74, range=27.279999999999998
# chas: min=0, max=1, range=1
# nox: min=0.385, max=0.871, range=0.486
# rm: min=3.561, max=8.78, range=5.218999999999999
# age: min=2.9, max=100.0, range=97.1
# dis: min=1.1296, max=12.1265, range=10.9969
# rad: min=1, max=24, range=23
# tax: min=187, max=711, range=524
# ptratio: min=12.6, max=22.0, range=9.4
# lstat: min=1.73, max=37.97, range=36.24
# medv: min=5.0, max=50.0, range=45.0
#
# Suburbs with particularly high crime rates (CRIM > 20):
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 379  23.6482  0.0   18.1     0  0.671  6.380   96.2  1.3861   24  666
# 381  88.9762  0.0   18.1     0  0.671  6.968   91.9  1.4165   24  666
# 385  20.0849  0.0   18.1     0  0.700  4.368   91.2  1.4395   24  666
# ...

# %% [markdown]
# (f) How many of the suburbs in this data set bound the Charles
# river?

# %%
boston["chas"].sum()
# Out:
# 35

# %% [markdown]
# What is the median pupil-teacher ratio among the towns in this
# data set?

# %%
median_ptratio = boston["ptratio"].median()

print(f"The median pupil-teacher ratio among the towns is: {median_ptratio}")
# Out:
# The median pupil-teacher ratio among the towns is: 19.05
